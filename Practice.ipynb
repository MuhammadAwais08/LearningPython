# %%
print("Hello World!")
# Out:
# Hello World!

# %%
def hello():
    print("Hello World!")
hello()
# Out:
# Hello World!

# %%
def my_name():
    print("My Name Is Muhammad Awais Raza")
my_name()
# Out:
# My Name Is Muhammad Awais Raza

# %%
def my_country():
    print('My Country Will Be Switzerland ,InshaAllah')
my_country()
# Out:
# My Country Will Be Switzerland ,InshaAllah

# %%
def morning():
    print("Good Morning!")
morning()
morning()
morning()
# Out:
# Good Morning!
# Good Morning!
# Good Morning!

# %%
def line():
    print("---------------------")
    print("|                    |")
    print("=====================")
line()
line()
line()
line()
line()
line()

# %% [markdown]
# ### Practice Functions Using One Parameter

# %%
def greet(name):
    print("Hello",name)
greet('Awais')
greet("Raza")
greet("Waqas")

# %%
def  my_city(city_name):
    print(f"I Live In {city_name}")
my_city("Islamabad")
my_city("Lahore")
# Out:
# I Live In Islamabad
# I Live In Lahore

# %%
def food(favouritefood):
    print(f"I like {favouritefood}")
food("Biryani")
food("Pizza")

def age(myAge):
    print(f"I'm {myAge} years old.")
age(21)

def animal(animal_name):
    print(f"My Favourite Animal Is {animal_name}")
animal("Lion")

# %% [markdown]
# ### Practice Functions Using Two Parameters

# %%
def add(x,y):
    print(f"The Sum Of Two Numbers Is {x+y}")
add(10,5)
add(20,34)
add(234,867)
#Multilplication Of Three Numbers
def multi(x,y,z):
    print("The Multiplication Of Three Numbers Is =",x*y*z)
multi(1,2,3)
multi(34,43,33)
multi(19,27,36)
# Out:
# The Sum Of Two Numbers Is 15
# The Sum Of Two Numbers Is 54
# The Sum Of Two Numbers Is 1101
# The Multiplication Of Three Numbers Is = 6
# The Multiplication Of Three Numbers Is = 48246
# The Multiplication Of Three Numbers Is = 18468

# %%
def intro(name,age,purpose_of_Life):
    print(f"My Name Is : {name} \nMy Age Is: {age}\nMy Purpose Of Life Is {purpose_of_Life} ")
intro('Muhammad Awais Raza',21,'To Become A AI Engineer')
# Out:
# My Name Is : Muhammad Awais Raza
# My Age Is: 21
# My Purpose Of Life Is To Become A AI Engineer

# %%
def add(num1,num2):
    c=num1+num2
    return c
result=add(10,20)
print("The Sum Of Two Numbers Is =",result)

def square(num):
    return num*num
result=square(5)
print("The Square Of The Number Is =",result)

def multi(x,y):
    z=x*y
    return z
result=multi(10,23)
print("The Multiplication Of Two Numbers Is =",result)
result=multi(14,24)
print("The Multiplication Of Two Numbers Is =",result)
# Out:
# The Sum Of Two Numbers Is = 30
# The Square Of The Number Is = 25
# The Multiplication Of Two Numbers Is = 230
# The Multiplication Of Two Numbers Is = 336

# %%
def my_ful_name(first_name, Last_name):
    full_name=first_name+Last_name
    return full_name
result=my_ful_name("Muhammad Awais", "Raza (Future AI Engineer)")
print("My Full Name Is ",result)
# Out:
# My Full Name Is  Muhammad AwaisRaza (Future AI Engineer)

# %%
def even_num(num):
    if num%2==0:
        return True
    else:
        return False
result=even_num(9)
print("Is The Number Even? ",result)
# Out:
# Is The Number Even?  False

# %% [markdown]
# ### Concept Of Local And Global Variables In Functions

# %%
#Local Variables use only inside the function and it unaccessible Outside The Functions
def my_name():
    name="Muhammad Awais Raza"
    age=21
    print(name ,age)
my_name()

city="Lahore"
def my_city():
    print(city)
my_city()

name="Awais"
def another_name():
    name="Raza"
    print(name)
another_name()
print(name)

#Country
country="Swizerland"
def my_country():
    print(country)
my_country()
print(country)
print(country)

# %%
x=100
def demo():
    x=50
    print(x)
print(x)
demo()
print(x)
# Out:
# 100
# 50
# 100

# %%
#agr mein aek function bnata hun jis ael function k andar calculator or aek function k bahir
x=int(input("Enter 1st Number="))
y=int(input("Enter 2nd Number="))
z=x+y
def sum():
    x=int(input("Enter 1st Number="))
    y=int(input("Enter 2nd Number="))
    z=x+y
    print(z)
sum()
print(z)
# Out:
# 4
# 2

# %%
def country():
    n1="Lahore"

print(n1)
country()
#we got error coz local isnt accesible outsidde the function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 def country():
#       2     n1="Lahore"
# ----> 4 print(n1)
#       5 country()
#
# NameError: name 'n1' is not defined

# %%
c="Finland"
def c1():
    print(c)
c1()
print(c)
# Out:
# Finland
# Finland

# %%
city="Quetta"
def city1():
    city="Karachi"
    print(city)
city1()
print(city)
# Out:
# Karachi
# Quetta

# %%
for harf in "python":
    print(harf)

for i in (0,21):
    if i==3:
        break
    print(i)

# %%
for i in range(1, 10):
    if i == 5:
        break 
    print(i) 

for i in range(1, 6):
    if i == 3:
        continue 
    print(i)

# %% [markdown]
# ### FizzBuzz

# %%
for i in range(1, 21):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
