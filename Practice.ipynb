# %%
print("Hello World!")
# Out:
# Hello World!

# %%
def hello():
    print("Hello World!")
hello()
# Out:
# Hello World!

# %%
def my_name():
    print("My Name Is Muhammad Awais Raza")
my_name()
# Out:
# My Name Is Muhammad Awais Raza

# %%
def my_country():
    print('My Country Will Be Switzerland ,InshaAllah')
my_country()
# Out:
# My Country Will Be Switzerland ,InshaAllah

# %%
def morning():
    print("Good Morning!")
morning()
morning()
morning()
# Out:
# Good Morning!
# Good Morning!
# Good Morning!

# %%
def line():
    print("---------------------")
    print("|                    |")
    print("=====================")
line()
line()
line()
line()
line()
line()
